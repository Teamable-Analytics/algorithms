# %%
from benchmarking.runs.priority_algorithm.larger_simple_runs.projects_run import (
    RegularClassSize,
)
from benchmarking.runs.priority_algorithm.larger_simple_runs.five_diversity_constraint import (
    FiveDiversityConstraint,
)

# %matplotlib widget

FiveDiversityConstraint().start()
# RegularClassSize().start()
# Out:
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# [WARNING]: No validation performed on harmony between student and initial teams providers when mock providers are not being used. Proceed with caution.
# ...
